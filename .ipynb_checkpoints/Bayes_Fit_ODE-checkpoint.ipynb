# %%
import numpy as np
import itertools
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp
import time

# import functions for ODE parameter estimation
from model.diag_Gaussian import *


np.random.seed(123)

# %% [markdown]
# ## Parameter estimation of ODE models:
#
# $$
# \frac{d \mathbf{x}}{d t} = f(\mathbf{x}, t, \theta)
# $$
# where $\mathbf{x}$ is a vector of state variables and $\theta$ is a vector of model parameters to be estimated from data

# %% [markdown]
# ## Define ODE (x, time, parameters)

# %%
# ode 
def system(x, t, params): 

    # unpack parameters
    K, pref, sigma, delta, gamma, mu, kdead = params
    
    # unpack variables
    od,
           
    # coupled ODE for cells and environmental pH
    ddead = -kdead*max(0,dead)
    dod = (od*(mu-od/K))*(np.exp(-(pH-pref)**2/sigma**2)-delta)+kdead*max(0,dead)
    dpH = gamma*od
    
    
    return [ddead, dod, dpH]  

# define transform function to constrain parameter values
def transform(params):
    
    # reshape parameters
    r = params[:n_s]
    A = jnp.reshape(params[n_s:], [n_s, n_s])

    # make sure growth rates are positive
    r = jnp.exp2(r)/10.

    # make sure self interactions are negative
    for i in range(n_s):
        A = A.at[i,i].set(-jnp.exp2(A[i,i]))
        
    return jnp.append(r, A.ravel())

# %% [markdown]
# ## Import data as a Pandas dataframe
#
# The dataframe must have a "Treatments" column that provides a unique identifier for each condition. The second column specifies the time point that observations were made. The following columns include the state variables.

# %%
# import data with different initial conditions 
# df = pd.read_csv("data/train_dataset.csv")

df = pd.read_csv("data/MS008_processed.csv")
df = pd.concat([df_i for exp_name, df_i in df.groupby("Treatments") if "Mono" not in exp_name])

# df = pd.read_csv("data/SusansData.csv")

# df = pd.read_csv("../Ostrem_Fiber_2023/data/MiRNN_data_inulin_fmt.csv").rename(columns={"Experiments":"Treatments"})

df
# Out:
#               Treatments  Time        CA        BT        BU   CS        CD  \
# 87           CH-DP-BT-BU   0.0  0.000000  0.002500  0.002500  0.0  0.000000
# 88           CH-DP-BT-BU  12.0  0.000000  0.726639  0.316787  0.0  0.000000
# 89           CH-DP-BT-BU  24.0  0.000000  0.633990  0.211766  0.0  0.000000
# 90           CH-DP-BU-CA   0.0  0.002500  0.000000  0.002500  0.0  0.000000
# 91           CH-DP-BU-CA  12.0  0.002391  0.000000  0.890796  0.0  0.000000
# ..                   ...   ...       ...       ...       ...  ...       ...
# 82  MS008-DP-BT-BU-BV-CA  12.0  0.003568  0.752347  0.126277  0.0  0.307087
# 83  MS008-DP-BT-BU-BV-CA  24.0  0.065093  0.771636  0.155679  0.0  0.055671
# 84        MS008-DP-BU-CA   0.0  0.002500  0.000000  0.002500  0.0  0.002500
# 85        MS008-DP-BU-CA  12.0  0.006165  0.000000  0.469328  0.0  0.415756
# 86        MS008-DP-BU-CA  24.0  0.123855  0.000000  0.428663  0.0  0.042363
#
#           DP        CH        BV
# 87  0.002500  0.002500  0.000000
# 88  0.036658  0.111416  0.000000
# 89  0.064840  0.106737  0.000000
# 90  0.002500  0.002500  0.000000
# 91  0.055984  0.142329  0.000000
# ..       ...       ...       ...
# 82  0.041542  0.000000  0.142012
# 83  0.103377  0.000000  0.055543
# 84  0.002500  0.000000  0.000000
# 85  0.049418  0.000000  0.000000
# 86  0.192452  0.000000  0.000000
#
# [177 rows x 10 columns]

# %%
df.describe()
# Out:
#              Time          CA          BT          BU          CS          CD  \
# count  177.000000  177.000000  177.000000  177.000000  177.000000  177.000000
# mean    12.000000    0.012242    0.269594    0.115499    0.025329    0.096271
# std      9.825755    0.028529    0.382159    0.176689    0.042913    0.176004
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%     12.000000    0.001667    0.001667    0.002500    0.002500    0.000000
# 75%     24.000000    0.004465    0.678905    0.181481    0.026448    0.148862
# max     24.000000    0.220172    1.168851    0.890796    0.187862    0.676758
#
#                DP          CH          BV
# count  177.000000  177.000000  177.000000
# mean     0.039181    0.046547    0.091581
# std      0.065661    0.080548    0.186465
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000
# 50%      0.002000    0.000000    0.000000
# 75%      0.056821    0.094665    0.121230
# max      0.348039    0.342231    0.954492

# %% [markdown]
# ## Specify system state variables

# %%
# names of species
species = df.columns.values[2:-1]

# global parameters used in ODE
n_s = len(species)

# %% [markdown]
# ## Define mean and standard deviation of Gaussian parameter prior

# %%
# define initial parameter guess
n_params = n_s + n_s**2 
params = np.zeros(n_params)

# set growth rates positive
params[:n_s] = .3

# set Aij terms zero and Aii terms negative 
params[n_s:] = 0.
k = n_s 
for i in range(n_s):
    for j in range(n_s):
        if i == j:
            params[k] = -1.
        k += 1
        
# mean of prior 
prior_mean = np.copy(params)

# %% [markdown]
# ## Instantiate the model with the ODE function, training dataframe, system variables, and initial parameter guess

# %%
# instantiate gLV fit 
ode_model = ODE(system = system, 
            transform = transform,
            dataframe = df, 
            sys_vars = species, 
            prior_mean = prior_mean, 
            alpha=1., beta=100.)

# %% [markdown]
# ## Fit the model using Maximum A Posteriori (MAP) estimate

# %%
# # fit to data 
# t0 = time.time()
# ode_model.fit_MAP_EM()
# print("Elapsed time {:.2f}s".format(time.time()-t0))

# %% [markdown]
# ## Show fit

# %%
# # random conditions to plot
# plt_conditions = np.random.choice(np.unique(df.Treatments.values), 5, replace=False)

# for exp_name in plt_conditions:
#     # pull dataframe
#     exp_df = df.iloc[df.Treatments.values==exp_name].copy()
    
#     # predict values
#     x0 = exp_df[species].values[0]
#     t_eval = np.linspace(0., max(exp_df.Time.values))
#     y_pred = ode_model.predict_point(x0, t_eval)
    
#     # plot 
#     for i, s in enumerate(species):
#         plt.scatter(exp_df.Time.values, exp_df[s].values)
#         plt.plot(t_eval, y_pred[:, i])
#     plt.show()

# %% [markdown]
# ## Fit the parameter posterior

# %%
# fit to data 
t0 = time.time()
ode_model.fit_posterior_EM(n_sample_sgd=1, 
                           n_sample_hypers=10, 
                           n_sample_evidence=100, 
                           patience=3)

print("Elapsed time {:.2f}s".format(time.time()-t0))
# Out:
# Computing model evidence...
# 100%|█████████████████████████████████████████| 100/100 [00:02<00:00, 42.71it/s]
# Log evidence: -3323.376
# Updating hyperparameters...
# 100%|███████████████████████████████████████████| 10/10 [00:00<00:00, 75.26it/s]
# Updating posterior...
# Epoch 1, NEG ELBO: 516.700
# Epoch 2, NEG ELBO: 506.573
# Epoch 3, NEG ELBO: 496.078
# Epoch 4, NEG ELBO: 485.947
# Epoch 5, NEG ELBO: 474.896
# Epoch 6, NEG ELBO: 462.529
# Epoch 7, NEG ELBO: 452.790
# Epoch 8, NEG ELBO: 439.283
# Epoch 9, NEG ELBO: 424.228
# Epoch 10, NEG ELBO: 407.689
# set lr to 1.100e-03
# Epoch 11, NEG ELBO: 399.304, Slope: -0.024
# set lr to 1.210e-03
# Epoch 12, NEG ELBO: 383.295, Slope: -0.025
# set lr to 1.331e-03
# Epoch 13, NEG ELBO: 370.481, Slope: -0.027
# set lr to 1.464e-03
# Epoch 14, NEG ELBO: 359.331, Slope: -0.028
# set lr to 1.611e-03
# Epoch 15, NEG ELBO: 348.142, Slope: -0.028
# set lr to 1.772e-03
# Epoch 16, NEG ELBO: 335.075, Slope: -0.029
# set lr to 1.949e-03
# Epoch 17, NEG ELBO: 327.299, Slope: -0.028
# set lr to 2.144e-03
# Epoch 18, NEG ELBO: 323.857, Slope: -0.027
# set lr to 2.358e-03
# Epoch 19, NEG ELBO: 314.137, Slope: -0.026
# set lr to 2.594e-03
# Epoch 20, NEG ELBO: 312.490, Slope: -0.024
# set lr to 2.853e-03
# Epoch 21, NEG ELBO: 304.838, Slope: -0.022
# set lr to 3.138e-03
# Epoch 22, NEG ELBO: 302.414, Slope: -0.020
# set lr to 3.452e-03
# Epoch 23, NEG ELBO: 302.447, Slope: -0.017
# set lr to 3.797e-03
# Epoch 24, NEG ELBO: 297.456, Slope: -0.015
# set lr to 4.177e-03
# Epoch 25, NEG ELBO: 304.306, Slope: -0.011
# Epoch 26, NEG ELBO: 300.268, Slope: -0.009
# Epoch 27, NEG ELBO: 310.754, Slope: -0.005
# Epoch 28, NEG ELBO: 303.502, Slope: -0.003
# Epoch 29, NEG ELBO: 306.873, Slope: -0.000
# decrease lr to 3.760e-03
# Epoch 30, NEG ELBO: 302.629, Slope: 0.001
# decrease lr to 3.384e-03
# Epoch 31, NEG ELBO: 297.693, Slope: 0.000
# decrease lr to 3.045e-03
# Epoch 32, NEG ELBO: 314.905, Slope: 0.002
# decrease lr to 2.741e-03
# Epoch 33, NEG ELBO: 308.368, Slope: 0.003
# decrease lr to 2.467e-03
# Epoch 34, NEG ELBO: 306.329, Slope: 0.001
# decrease lr to 2.220e-03
# Epoch 35, NEG ELBO: 303.694, Slope: 0.001
# Epoch 36, NEG ELBO: 300.776, Slope: -0.001
# decrease lr to 1.998e-03
# Epoch 37, NEG ELBO: 307.582, Slope: 0.000
# Epoch 38, NEG ELBO: 294.540, Slope: -0.002
# Epoch 39, NEG ELBO: 294.492, Slope: -0.003
# Epoch 40, NEG ELBO: 295.942, Slope: -0.004
# Epoch 41, NEG ELBO: 303.152, Slope: -0.005
# Epoch 42, NEG ELBO: 304.687, Slope: -0.002
# Epoch 43, NEG ELBO: 301.570, Slope: -0.001
# Epoch 44, NEG ELBO: 295.243, Slope: -0.001
# Epoch 45, NEG ELBO: 300.929, Slope: -0.000
# Epoch 46, NEG ELBO: 292.854, Slope: -0.001
# decrease lr to 1.798e-03
# Epoch 47, NEG ELBO: 296.858, Slope: 0.000
# decrease lr to 1.618e-03
# Epoch 48, NEG ELBO: 302.037, Slope: 0.000
# decrease lr to 1.457e-03
# Epoch 49, NEG ELBO: 305.509, Slope: 0.000
# decrease lr to 1.311e-03
# Epoch 50, NEG ELBO: 303.108, Slope: 0.000
# decrease lr to 1.180e-03
# Epoch 51, NEG ELBO: 306.223, Slope: 0.002
# decrease lr to 1.062e-03
# Epoch 52, NEG ELBO: 306.102, Slope: 0.003
# decrease lr to 9.556e-04
# Epoch 53, NEG ELBO: 297.838, Slope: 0.003
# decrease lr to 1.720e-03
# Epoch 54, NEG ELBO: 299.441, Slope: 0.002
# decrease lr to 1.548e-03
# Epoch 55, NEG ELBO: 311.423, Slope: 0.003
# decrease lr to 1.393e-03
# Epoch 56, NEG ELBO: 316.149, Slope: 0.004
# decrease lr to 1.254e-03
# Epoch 57, NEG ELBO: 293.909, Slope: 0.000
# Epoch 58, NEG ELBO: 298.890, Slope: -0.001
# Epoch 59, NEG ELBO: 294.805, Slope: -0.002
# Epoch 60, NEG ELBO: 302.082, Slope: -0.002
# Epoch 61, NEG ELBO: 302.730, Slope: -0.002
# Epoch 62, NEG ELBO: 295.148, Slope: -0.002
# Epoch 63, NEG ELBO: 299.468, Slope: -0.003
# Epoch 64, NEG ELBO: 296.100, Slope: -0.004
# Epoch 65, NEG ELBO: 308.864, Slope: -0.001
# decrease lr to 1.129e-03
# Epoch 66, NEG ELBO: 298.890, Slope: 0.002
# decrease lr to 1.016e-03
# Epoch 67, NEG ELBO: 298.018, Slope: 0.001
# decrease lr to 9.141e-04
# Epoch 68, NEG ELBO: 312.683, Slope: 0.003
# decrease lr to 1.645e-03
# Epoch 69, NEG ELBO: 303.633, Slope: 0.002
# decrease lr to 1.481e-03
# Epoch 70, NEG ELBO: 300.936, Slope: 0.002
# decrease lr to 1.333e-03
# Epoch 71, NEG ELBO: 297.412, Slope: 0.002
# Epoch 72, NEG ELBO: 295.907, Slope: -0.001
# Epoch 73, NEG ELBO: 302.523, Slope: -0.001
# Epoch 74, NEG ELBO: 302.402, Slope: -0.002
# Epoch 75, NEG ELBO: 298.058, Slope: -0.001
# Epoch 76, NEG ELBO: 303.077, Slope: -0.001
# Epoch 77, NEG ELBO: 309.794, Slope: -0.000
# decrease lr to 1.200e-03
# Epoch 78, NEG ELBO: 302.213, Slope: 0.002
# decrease lr to 1.080e-03
# Epoch 79, NEG ELBO: 300.320, Slope: 0.002
# decrease lr to 9.716e-04
# Computing model evidence...
# 100%|█████████████████████████████████████████| 100/100 [00:01<00:00, 83.12it/s]
# Log evidence: 476.567
# Updating hyperparameters...
# 100%|███████████████████████████████████████████| 10/10 [00:00<00:00, 76.95it/s]
# Updating posterior...
# Epoch 1, NEG ELBO: 382.373
# Epoch 2, NEG ELBO: 397.353
# Epoch 3, NEG ELBO: 406.156
# Epoch 4, NEG ELBO: 407.658
# Epoch 5, NEG ELBO: 389.195
# Epoch 6, NEG ELBO: 389.084
# Epoch 7, NEG ELBO: 389.544
# Epoch 8, NEG ELBO: 376.586
# Epoch 9, NEG ELBO: 392.004
# Epoch 10, NEG ELBO: 392.502
# Epoch 11, NEG ELBO: 385.753, Slope: -0.005
# Epoch 12, NEG ELBO: 370.693, Slope: -0.007
# Epoch 13, NEG ELBO: 381.976, Slope: -0.005
# Epoch 14, NEG ELBO: 386.344, Slope: -0.002
# Epoch 15, NEG ELBO: 376.691, Slope: -0.003
# Epoch 16, NEG ELBO: 386.784, Slope: -0.002
# Epoch 17, NEG ELBO: 373.614, Slope: -0.002
# Epoch 18, NEG ELBO: 399.849, Slope: -0.001
# Epoch 19, NEG ELBO: 375.973, Slope: -0.000
# Epoch 20, NEG ELBO: 368.626, Slope: -0.001
# decrease lr to 9.000e-04
# Epoch 21, NEG ELBO: 383.812, Slope: 0.000
# Epoch 22, NEG ELBO: 381.517, Slope: -0.001
# Epoch 23, NEG ELBO: 383.537, Slope: -0.001
# decrease lr to 1.620e-03
# Epoch 24, NEG ELBO: 385.142, Slope: 0.001
# decrease lr to 1.458e-03
# Epoch 25, NEG ELBO: 396.132, Slope: 0.002
# decrease lr to 1.312e-03
# Epoch 26, NEG ELBO: 377.071, Slope: 0.001
# Epoch 27, NEG ELBO: 376.105, Slope: -0.001
# decrease lr to 1.181e-03
# Epoch 28, NEG ELBO: 378.612, Slope: 0.001
# decrease lr to 1.063e-03
# Epoch 29, NEG ELBO: 389.783, Slope: 0.002
# Epoch 30, NEG ELBO: 381.551, Slope: -0.001
# Epoch 31, NEG ELBO: 377.983, Slope: -0.001
# Epoch 32, NEG ELBO: 390.228, Slope: -0.000
# Epoch 33, NEG ELBO: 384.179, Slope: -0.000
# Epoch 34, NEG ELBO: 364.594, Slope: -0.003
# Epoch 35, NEG ELBO: 372.901, Slope: -0.001
# Epoch 36, NEG ELBO: 391.108, Slope: -0.000
# Epoch 37, NEG ELBO: 369.992, Slope: -0.002
# Epoch 38, NEG ELBO: 391.663, Slope: -0.001
# decrease lr to 9.566e-04
# Epoch 39, NEG ELBO: 381.245, Slope: 0.000
# decrease lr to 1.722e-03
# Epoch 40, NEG ELBO: 384.128, Slope: 0.001
# decrease lr to 1.550e-03
# Epoch 41, NEG ELBO: 383.133, Slope: 0.001
# decrease lr to 1.395e-03
# Epoch 42, NEG ELBO: 385.161, Slope: 0.003
# decrease lr to 1.255e-03
# Epoch 43, NEG ELBO: 407.467, Slope: 0.007
# decrease lr to 1.130e-03
# Epoch 44, NEG ELBO: 376.116, Slope: 0.003
# decrease lr to 1.017e-03
# Epoch 45, NEG ELBO: 377.449, Slope: 0.000
# decrease lr to 9.151e-04
# Computing model evidence...
# 100%|█████████████████████████████████████████| 100/100 [00:01<00:00, 83.14it/s]
# Log evidence: 679.376
# Updating hyperparameters...
# 100%|███████████████████████████████████████████| 10/10 [00:00<00:00, 75.53it/s]
# Updating posterior...
# Epoch 1, NEG ELBO: 399.097
# Epoch 2, NEG ELBO: 398.389
# Epoch 3, NEG ELBO: 402.285
# Epoch 4, NEG ELBO: 389.154
# Epoch 5, NEG ELBO: 407.573
# Epoch 6, NEG ELBO: 391.712
# Epoch 7, NEG ELBO: 394.866
# Epoch 8, NEG ELBO: 403.913
# Epoch 9, NEG ELBO: 400.270
# Epoch 10, NEG ELBO: 402.458
# Epoch 11, NEG ELBO: 379.313, Slope: -0.002
# decrease lr to 9.000e-04
# Epoch 12, NEG ELBO: 417.985, Slope: 0.001
# decrease lr to 1.620e-03
# Epoch 13, NEG ELBO: 388.490, Slope: 0.000
# Epoch 14, NEG ELBO: 391.934, Slope: -0.002
# Epoch 15, NEG ELBO: 386.673, Slope: -0.002
# Epoch 16, NEG ELBO: 399.770, Slope: -0.002
# Epoch 17, NEG ELBO: 392.804, Slope: -0.003
# Epoch 18, NEG ELBO: 391.931, Slope: -0.002
# Epoch 19, NEG ELBO: 384.116, Slope: -0.003
# Epoch 20, NEG ELBO: 397.367, Slope: -0.001
# Epoch 21, NEG ELBO: 394.584, Slope: -0.003
# decrease lr to 1.458e-03
# Epoch 22, NEG ELBO: 395.505, Slope: 0.001
# Epoch 23, NEG ELBO: 379.469, Slope: -0.001
# Epoch 24, NEG ELBO: 378.269, Slope: -0.003
# Epoch 25, NEG ELBO: 412.649, Slope: -0.000
# decrease lr to 1.312e-03
# Epoch 26, NEG ELBO: 395.969, Slope: 0.001
# decrease lr to 1.181e-03
# Epoch 27, NEG ELBO: 385.678, Slope: 0.001
# decrease lr to 1.063e-03
# Epoch 28, NEG ELBO: 398.225, Slope: 0.002
# Epoch 29, NEG ELBO: 385.504, Slope: -0.001
# Epoch 30, NEG ELBO: 390.613, Slope: -0.000
# decrease lr to 9.566e-04
# Epoch 31, NEG ELBO: 390.395, Slope: 0.000
# Epoch 32, NEG ELBO: 383.979, Slope: -0.000
# Epoch 33, NEG ELBO: 402.199, Slope: -0.000
# Epoch 34, NEG ELBO: 387.056, Slope: -0.003
# decrease lr to 1.722e-03
# Epoch 35, NEG ELBO: 406.970, Slope: 0.002
# decrease lr to 1.550e-03
# Epoch 36, NEG ELBO: 413.567, Slope: 0.005
# decrease lr to 1.395e-03
# Epoch 37, NEG ELBO: 389.093, Slope: 0.003
# decrease lr to 1.255e-03
# Epoch 38, NEG ELBO: 402.820, Slope: 0.005
# decrease lr to 1.130e-03
# Epoch 39, NEG ELBO: 385.114, Slope: 0.002
# decrease lr to 1.017e-03
# Epoch 40, NEG ELBO: 397.286, Slope: 0.001
# Epoch 41, NEG ELBO: 386.571, Slope: -0.001
# Epoch 42, NEG ELBO: 381.329, Slope: -0.005
# Epoch 43, NEG ELBO: 386.654, Slope: -0.005
# Epoch 44, NEG ELBO: 386.374, Slope: -0.007
# Epoch 45, NEG ELBO: 385.817, Slope: -0.005
# Epoch 46, NEG ELBO: 383.240, Slope: -0.003
# Epoch 47, NEG ELBO: 394.494, Slope: -0.002
# decrease lr to 9.151e-04
# Computing model evidence...
# 100%|█████████████████████████████████████████| 100/100 [00:01<00:00, 83.42it/s]
# Log evidence: 567.766
# Updating hyperparameters...
# 100%|███████████████████████████████████████████| 10/10 [00:00<00:00, 82.26it/s]
# Updating posterior...
# Epoch 1, NEG ELBO: 413.521
# Epoch 2, NEG ELBO: 407.163
# Epoch 3, NEG ELBO: 409.542
# Epoch 4, NEG ELBO: 419.938
# Epoch 5, NEG ELBO: 407.657
# Epoch 6, NEG ELBO: 397.472
# Epoch 7, NEG ELBO: 402.832
# Epoch 8, NEG ELBO: 401.767
# Epoch 9, NEG ELBO: 388.008
# Epoch 10, NEG ELBO: 409.715
# Epoch 11, NEG ELBO: 403.486, Slope: -0.003
# Epoch 12, NEG ELBO: 394.252, Slope: -0.004
# Epoch 13, NEG ELBO: 396.250, Slope: -0.004
# Epoch 14, NEG ELBO: 386.396, Slope: -0.003
# Epoch 15, NEG ELBO: 399.811, Slope: -0.002
# decrease lr to 9.000e-04
# Epoch 16, NEG ELBO: 412.425, Slope: 0.000
# Epoch 17, NEG ELBO: 383.663, Slope: -0.001
# Epoch 18, NEG ELBO: 386.966, Slope: -0.002
# Epoch 19, NEG ELBO: 391.164, Slope: -0.004
# Epoch 20, NEG ELBO: 405.927, Slope: -0.001
# decrease lr to 1.620e-03
# Epoch 21, NEG ELBO: 394.361, Slope: 0.000
# decrease lr to 1.458e-03
# Epoch 22, NEG ELBO: 394.449, Slope: 0.000
# Epoch 23, NEG ELBO: 392.517, Slope: -0.000
# Epoch 24, NEG ELBO: 394.064, Slope: -0.001
# Epoch 25, NEG ELBO: 383.351, Slope: -0.002
# decrease lr to 1.312e-03
# Epoch 26, NEG ELBO: 404.376, Slope: 0.002
# decrease lr to 1.181e-03
# Epoch 27, NEG ELBO: 390.799, Slope: 0.000
# Epoch 28, NEG ELBO: 385.958, Slope: -0.002
# Epoch 29, NEG ELBO: 397.235, Slope: -0.002
# Epoch 30, NEG ELBO: 394.378, Slope: -0.000
# decrease lr to 1.063e-03
# Epoch 31, NEG ELBO: 395.585, Slope: 0.000
# Epoch 32, NEG ELBO: 384.965, Slope: -0.000
# Epoch 33, NEG ELBO: 390.127, Slope: -0.001
# Epoch 34, NEG ELBO: 383.296, Slope: -0.002
# Epoch 35, NEG ELBO: 394.876, Slope: -0.002
# Epoch 36, NEG ELBO: 391.610, Slope: -0.000
# Epoch 37, NEG ELBO: 389.702, Slope: -0.001
# decrease lr to 9.566e-04
# Epoch 38, NEG ELBO: 404.288, Slope: 0.001
# decrease lr to 1.722e-03
# Epoch 39, NEG ELBO: 401.374, Slope: 0.002
# decrease lr to 1.550e-03
# Epoch 40, NEG ELBO: 381.037, Slope: 0.001
# decrease lr to 1.395e-03
# Epoch 41, NEG ELBO: 379.636, Slope: 0.000
# decrease lr to 1.255e-03
# Epoch 42, NEG ELBO: 399.465, Slope: 0.000
# Epoch 43, NEG ELBO: 384.746, Slope: -0.001
# Epoch 44, NEG ELBO: 396.099, Slope: -0.001
# Epoch 45, NEG ELBO: 393.819, Slope: -0.001
# Epoch 46, NEG ELBO: 382.510, Slope: -0.002
# Epoch 47, NEG ELBO: 400.797, Slope: -0.001
# decrease lr to 1.130e-03
# Epoch 48, NEG ELBO: 392.856, Slope: 0.001
# decrease lr to 1.017e-03
# Epoch 49, NEG ELBO: 384.828, Slope: 0.002
# decrease lr to 9.151e-04
# Computing model evidence...
# 100%|█████████████████████████████████████████| 100/100 [00:01<00:00, 83.29it/s]
# Log evidence: 498.344
# Updating hyperparameters...
# 100%|███████████████████████████████████████████| 10/10 [00:00<00:00, 82.08it/s]
# Updating posterior...
# Epoch 1, NEG ELBO: 402.555
# Epoch 2, NEG ELBO: 403.488
# Epoch 3, NEG ELBO: 390.976
# Epoch 4, NEG ELBO: 412.848
# Epoch 5, NEG ELBO: 399.014
# Epoch 6, NEG ELBO: 394.870
# Epoch 7, NEG ELBO: 389.570
# Epoch 8, NEG ELBO: 402.579
# Epoch 9, NEG ELBO: 421.377
# Epoch 10, NEG ELBO: 388.465
# Epoch 11, NEG ELBO: 396.574, Slope: -0.000
# Epoch 12, NEG ELBO: 399.181, Slope: -0.000
# Epoch 13, NEG ELBO: 394.064, Slope: -0.002
# Epoch 14, NEG ELBO: 386.270, Slope: -0.002
# Epoch 15, NEG ELBO: 383.520, Slope: -0.003
# Epoch 16, NEG ELBO: 387.601, Slope: -0.004
# Epoch 17, NEG ELBO: 390.211, Slope: -0.006
# Epoch 18, NEG ELBO: 392.099, Slope: -0.005
# Epoch 19, NEG ELBO: 396.159, Slope: -0.000
# Epoch 20, NEG ELBO: 394.606, Slope: -0.000
# decrease lr to 9.000e-04
# Epoch 21, NEG ELBO: 398.852, Slope: 0.001
# decrease lr to 1.620e-03
# Epoch 22, NEG ELBO: 393.369, Slope: 0.003
# decrease lr to 1.458e-03
# Epoch 23, NEG ELBO: 399.157, Slope: 0.004
# decrease lr to 1.312e-03
# Epoch 24, NEG ELBO: 389.209, Slope: 0.003
# decrease lr to 1.181e-03
# Epoch 25, NEG ELBO: 387.916, Slope: 0.000
# decrease lr to 1.063e-03
# Epoch 26, NEG ELBO: 428.099, Slope: 0.004
# decrease lr to 9.566e-04
# Epoch 27, NEG ELBO: 414.368, Slope: 0.005
# decrease lr to 1.722e-03
# Epoch 28, NEG ELBO: 387.461, Slope: 0.003
# Epoch 29, NEG ELBO: 381.010, Slope: -0.000
# Epoch 30, NEG ELBO: 389.495, Slope: -0.002
# Epoch 31, NEG ELBO: 389.807, Slope: -0.002
# Epoch 32, NEG ELBO: 397.584, Slope: -0.002
# Epoch 33, NEG ELBO: 394.068, Slope: -0.002
# Epoch 34, NEG ELBO: 410.258, Slope: -0.001
# Epoch 35, NEG ELBO: 394.775, Slope: -0.003
# Epoch 36, NEG ELBO: 379.691, Slope: -0.001
# decrease lr to 1.550e-03
# Epoch 37, NEG ELBO: 395.918, Slope: 0.002
# decrease lr to 1.395e-03
# Epoch 38, NEG ELBO: 387.821, Slope: 0.001
# Epoch 39, NEG ELBO: 388.153, Slope: -0.001
# Epoch 40, NEG ELBO: 404.503, Slope: -0.000
# decrease lr to 1.255e-03
# Epoch 41, NEG ELBO: 411.474, Slope: 0.001
# decrease lr to 1.130e-03
# Epoch 42, NEG ELBO: 399.367, Slope: 0.002
# decrease lr to 1.017e-03
# Epoch 43, NEG ELBO: 402.103, Slope: 0.002
# decrease lr to 9.151e-04
# Computing model evidence...
# 100%|█████████████████████████████████████████| 100/100 [00:01<00:00, 82.84it/s]
# Log evidence: 337.235
# Elapsed time 34.08s

# %%
# random conditions to plot
plt_conditions = np.random.choice(np.unique(df.Treatments.values), 5, replace=False)

for exp_name in plt_conditions:
    # pull dataframe
    exp_df = df.iloc[df.Treatments.values==exp_name].copy()
    
    # predict values
    x0 = exp_df[species].values[0]
    t_eval = np.linspace(0., max(exp_df.Time.values))
    y_preds = ode_model.predict_sample(x0, t_eval)
    
    # plot 
    for i, s in enumerate(species):
        plt.scatter(exp_df.Time.values, exp_df[s].values)
        for y_pred in y_preds:
            plt.plot(t_eval, y_pred[:, i], alpha=.3, c=f'C{i}')
    
    plt.title(exp_name)
    plt.show()

# %% [markdown]
# ## Save parameter values

# %%
# Define names of parameters 
df_params = ode_model.param_df()
df_params
# Out:
#         mean      stdv
# 0   0.141912  0.005590
# 1   0.746163  0.013631
# 2   0.596603  0.016755
# 3   0.246103  0.009974
# 4   0.622165  0.024299
# 5   0.308563  0.009311
# 6   0.434291  0.014050
# 7  -1.098806  0.157604
# 8  -0.012533  0.016702
# 9   0.020998  0.032422
# 10  0.121023  0.146549
# 11  0.025373  0.041582
# 12  0.110423  0.081132
# 13  0.065858  0.063985
# 14 -0.030962  0.192668
# 15 -0.829387  0.021878
# 16 -0.351091  0.086373
# 17 -0.044880  0.170157
# 18 -0.030534  0.094739
# 19 -0.012319  0.149611
# 20 -0.522066  0.132552
# 21 -0.046719  0.213938
# 22 -0.457383  0.038186
# 23 -1.271157  0.068877
# 24 -0.078725  0.208035
# 25 -0.032076  0.102403
# 26 -0.046073  0.160233
# 27 -0.010984  0.125924
# 28 -0.012925  0.191254
# 29 -0.038876  0.017637
# 30 -0.090959  0.046226
# 31 -1.065464  0.144092
# 32 -0.385371  0.076659
# 33 -0.031683  0.106245
# 34 -0.588674  0.088530
# 35 -0.033620  0.192950
# 36 -0.383897  0.059971
# 37 -0.438317  0.101609
# 38 -0.016415  0.207693
# 39 -1.303941  0.077570
# 40 -0.202881  0.189357
# 41 -0.135042  0.172910
# 42  0.016893  0.169831
# 43 -0.109874  0.019882
# 44 -0.068825  0.042212
# 45  0.045185  0.159783
# 46 -0.234484  0.049498
# 47 -1.127279  0.085439
# 48 -0.375261  0.080808
# 49 -0.139556  0.187761
# 50 -0.142545  0.030450
# 51 -0.082301  0.062010
# 52  0.008538  0.206442
# 53 -0.511853  0.077166
# 54 -0.121368  0.143207
# 55 -1.502086  0.085298
